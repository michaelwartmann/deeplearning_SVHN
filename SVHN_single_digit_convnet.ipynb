# %%
from __future__ import print_function
import numpy as np
import tensorflow as tf
from six.moves import cPickle as pickle
from six.moves import range
from datetime import datetime
tf.test.is_gpu_available()
# Out:
# True

# %%
# unpickle

pickle_file = 'SVHN.pickle'

with open(pickle_file, 'rb') as f:
    save = pickle.load(f)
    train_dataset = save['train_dataset']
    train_labels = save['train_labels']
    valid_dataset = save['valid_dataset']
    valid_labels = save['valid_labels']
    test_dataset = save['test_dataset']
    test_labels = save['test_labels']
    del save  # hint to help gc free up memory
    
    
pickle_file = 'SVHN_extra.pickle'

with open(pickle_file, 'rb') as f:
    save = pickle.load(f)
    train2_dataset = save['train2_dataset']
    train2_labels = save['train2_labels']
    del save  # hint to help gc free up memory

pickle_file = 'SVHN_extra2.pickle'

with open(pickle_file, 'rb') as f:
    save = pickle.load(f)
    train3_dataset = save['train3_dataset']
    train3_labels = save['train3_labels']
    del save  # hint to help gc free up memory

print('Training set', train_dataset.shape, train_labels.shape)
print('Training set extra 1', train2_dataset.shape, train2_labels.shape)
print('Training set extra 2', train3_dataset.shape, train3_labels.shape)
print('Validation set', valid_dataset.shape, valid_labels.shape)
print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 32, 32) (200000,)
# Training set extra 1 (200000, 32, 32) (200000,)
# Training set extra 2 (143949, 32, 32) (143949,)
# Validation set (60439, 32, 32) (60439,)
# Test set (26032, 32, 32) (26032,)

# %%
# concatenate training sets
train_dataset = np.concatenate((train_dataset, train2_dataset, train3_dataset), axis=0)
train_labels = np.concatenate((train_labels, train2_labels, train3_labels), axis=0)
del train2_dataset, train3_dataset, train2_labels, train3_labels
print('Training set', train_dataset.shape, train_labels.shape)
print('Validation set', valid_dataset.shape, valid_labels.shape)
print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (543949, 32, 32) (543949,)
# Validation set (60439, 32, 32) (60439,)
# Test set (26032, 32, 32) (26032,)

# %%
# reformat dataset for training

image_size = 32
num_labels = 10
num_channels = 1 # grayscale

def reformat(dataset, labels):
    dataset = dataset.reshape((-1, image_size, image_size, num_channels)).astype(np.float32)
    labels = labels.astype(np.int32)
    return dataset, labels

train_dataset, train_labels = reformat(train_dataset, train_labels)
valid_dataset, valid_labels = reformat(valid_dataset, valid_labels)
test_dataset, test_labels = reformat(test_dataset, test_labels)

print('Training set', train_dataset.shape, train_labels.shape)
print('Validation set', valid_dataset.shape, valid_labels.shape)
print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (543949, 32, 32, 1) (543949,)
# Validation set (60439, 32, 32, 1) (60439,)
# Test set (26032, 32, 32, 1) (26032,)

# %%
# helper methods for creating CNN
def weight_variable(shape):
    initial = tf.truncated_normal(shape, stddev=0.1)
    return tf.Variable(initial)

def bias_variable(shape):
    initial = tf.constant(0.1, shape=shape)
    return tf.Variable(initial)

def conv2d_same(x, W):
    return tf.nn.conv2d(x, W, strides=[1, 1, 1, 1], padding='SAME')

def conv2d_valid(x, W):
    return tf.nn.conv2d(x, W, strides=[1, 1, 1, 1], padding='VALID')

def max_pool_2x2(x):
    return tf.nn.max_pool(x, ksize=[1, 2, 2, 1],strides=[1, 2, 2, 1], padding='SAME')

def accuracy(predictions, labels):
    return (100.0 * np.sum(np.argmax(predictions, 1) == labels) / predictions.shape[0])

# %%
# define parameters for model

batch_size = 64
patch_size = 5
depth1 = 16
depth2 = 32
depth3 = 64
num_hidden1 = 64
num_hidden2 = 16
shape=[batch_size, image_size, image_size, num_channels]

graph = tf.Graph()

with graph.as_default():

    # Input parameters
    tf_train_dataset = tf.placeholder(tf.float32, shape=(batch_size, image_size, image_size, num_channels))
    tf_train_labels = tf.placeholder(tf.int64, shape=(batch_size))
    tf_valid_dataset = tf.constant(valid_dataset)
    tf_test_dataset = tf.constant(test_dataset)
  

    # Weight and bias variables
    W_C1 = weight_variable([patch_size, patch_size, num_channels, depth1])
    b_C1 = tf.Variable(tf.constant(1.0, shape=[depth1]), name='B1')
    
    W_C2 = weight_variable([patch_size, patch_size, depth1, depth2])
    b_C2 = tf.Variable(tf.constant(1.0, shape=[depth2]), name='B2')
    
    W_C3 = weight_variable([patch_size, patch_size, depth2, num_hidden1])
    b_C3 = tf.Variable(tf.constant(1.0, shape=[num_hidden1]), name='B3')
    
    W_C4 = weight_variable([num_hidden1, num_hidden2])
    b_C4 = tf.Variable(tf.constant(1.0, shape=[num_hidden2]), name='B4')
    
    W_C5 = weight_variable([num_hidden2, num_labels])
    b_C5 = tf.Variable(tf.constant(1.0, shape=[num_labels]), name='B5')
  
    # neural network model
    def model(data, keep_prob, shape):
        # C1: convolutional layer, batch_size x 28 x 28 x 16, convolution size: 5 x 5 x 1 x 16
        conv =conv2d_valid(data, W_C1)
        hconv = tf.nn.relu(conv + b_C1)
        
        #Local response normalization
        lrn = tf.nn.local_response_normalization(hconv)
        
        # S2: sub-sampling layer, batch_size x 14 x 14 x 16
        maxpool = max_pool_2x2(lrn)
        
        # C3: convolutional layer, batch_size x 10 x 10 x 32, convolution size: 5 x 5 x 16 x 32
        conv =conv2d_valid(maxpool, W_C2)
        hconv = tf.nn.relu(conv + b_C2)
        
        #Local response normalization
        lrn = tf.nn.local_response_normalization(hconv)
        
        # S4: sub-sampling layer, batch_size x 5 x 5 x 32
        maxpool = max_pool_2x2(lrn)
        
        # C5: convolutional layer, batch_size x 1 x 1 x 64, convolution size: 5 x 5 x 32 x 64
        conv =conv2d_valid(maxpool, W_C3)
        hconv = tf.nn.relu(conv + b_C3)
        
        # Dropout
        dropout = tf.nn.dropout(hconv, keep_prob)
        
        # Reshaping tensor for fully connected layers
        shape = dropout.get_shape().as_list()
        flattened = tf.reshape(dropout, [shape[0], shape[1] * shape[2] * shape[3]])
        
        # F6: fully-connected layer, shape: 64 x 16
        FC = tf.nn.relu(tf.matmul(flattened, W_C4) + b_C4)
        
        # Output layer, weight size: 16 x 10
        return tf.matmul(FC, W_C5) + b_C5
    
    # defining logits and loss function
    logits = model(tf_train_dataset, 0.9, shape)
    loss = tf.reduce_mean(tf.nn.sparse_softmax_cross_entropy_with_logits(logits, tf_train_labels))
    
    # Defining learning rate and optimizer
    global_step = tf.Variable(0)
    learning_rate = 0.1
    optimizer = tf.train.GradientDescentOptimizer(learning_rate).minimize(loss, global_step=global_step)
  
    # Predictions for the training, validation, and test data.
    train_prediction = tf.nn.softmax(model(tf_train_dataset, 1.0, shape))
    valid_prediction = tf.nn.softmax(model(tf_valid_dataset, 1.0, shape))
    test_prediction = tf.nn.softmax(model(tf_test_dataset, 1.0, shape))
    
    # Save model
    saver = tf.train.Saver()

# %%
# starting session and run computation

num_steps = 200001
print('Training start time: ', str(datetime.now()))
with tf.Session(graph=graph,config=tf.ConfigProto(log_device_placement=True)) as session:
    tf.initialize_all_variables().run()
    print('Initialized')
    for step in range(num_steps):
        offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
        batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
        batch_labels = train_labels[offset:(offset + batch_size)]
        feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
        _, l, predictions = session.run([optimizer, loss, train_prediction], feed_dict=feed_dict)
        if (step % 500 == 0): 
            print('Minibatch loss at step %d: %f' % (step, l))
            print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
            print('Validation accuracy: %.1f%%' % accuracy(valid_prediction.eval(), valid_labels))
    print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
    save_path = saver.save(session, "SVHN_single.ckpt")
    print('Training end time: ', str(datetime.now()))
    print("Model saved in file: %s" % save_path)
# Out:
# Training start time:  2016-12-01 19:23:48.771280
# Initialized
# Minibatch loss at step 0: 2.531307
# Minibatch accuracy: 10.9%
# Validation accuracy: 14.2%
# Minibatch loss at step 500: 0.645538
# Minibatch accuracy: 85.9%
# Validation accuracy: 82.0%
# Minibatch loss at step 1000: 0.426315
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.8%
# Minibatch loss at step 1500: 0.321635
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.8%
# Minibatch loss at step 2000: 0.430683
# Minibatch accuracy: 87.5%
# Validation accuracy: 91.5%
# Minibatch loss at step 2500: 0.308262
# Minibatch accuracy: 92.2%
# Validation accuracy: 91.6%
# Minibatch loss at step 3000: 0.390852
# Minibatch accuracy: 90.6%
# Validation accuracy: 92.8%
# Minibatch loss at step 3500: 0.202205
# Minibatch accuracy: 93.8%
# Validation accuracy: 92.8%
# Minibatch loss at step 4000: 0.155466
# Minibatch accuracy: 95.3%
# Validation accuracy: 93.0%
# Minibatch loss at step 4500: 0.292037
# Minibatch accuracy: 90.6%
# Validation accuracy: 93.4%
# Minibatch loss at step 5000: 0.273475
# Minibatch accuracy: 93.8%
# Validation accuracy: 93.6%
# Minibatch loss at step 5500: 0.199373
# Minibatch accuracy: 93.8%
# Validation accuracy: 93.4%
# Minibatch loss at step 6000: 0.402083
# Minibatch accuracy: 89.1%
# Validation accuracy: 93.7%
# Minibatch loss at step 6500: 0.249706
# Minibatch accuracy: 92.2%
# Validation accuracy: 94.1%
# Minibatch loss at step 7000: 0.097237
# Minibatch accuracy: 96.9%
# Validation accuracy: 94.1%
# Minibatch loss at step 7500: 0.086633
# Minibatch accuracy: 96.9%
# Validation accuracy: 94.3%
# Minibatch loss at step 8000: 0.093282
# Minibatch accuracy: 93.8%
# Validation accuracy: 94.2%
# Minibatch loss at step 8500: 0.227493
# Minibatch accuracy: 95.3%
# Validation accuracy: 94.3%
# Minibatch loss at step 9000: 0.142392
# Minibatch accuracy: 92.2%
# Validation accuracy: 94.3%
# Minibatch loss at step 9500: 0.160779
# Minibatch accuracy: 95.3%
# Validation accuracy: 94.6%
# Minibatch loss at step 10000: 0.192753
# Minibatch accuracy: 96.9%
# Validation accuracy: 94.3%
# Minibatch loss at step 10500: 0.208062
# Minibatch accuracy: 93.8%
# Validation accuracy: 94.7%
# Minibatch loss at step 11000: 0.480782
# Minibatch accuracy: 89.1%
# Validation accuracy: 94.6%
# Minibatch loss at step 11500: 0.126484
# Minibatch accuracy: 96.9%
# Validation accuracy: 94.9%
# Minibatch loss at step 12000: 0.047060
# Minibatch accuracy: 98.4%
# Validation accuracy: 94.9%
# Minibatch loss at step 12500: 0.051694
# Minibatch accuracy: 96.9%
# Validation accuracy: 94.9%
# Minibatch loss at step 13000: 0.195848
# Minibatch accuracy: 92.2%
# Validation accuracy: 94.9%
# Minibatch loss at step 13500: 0.091232
# Minibatch accuracy: 96.9%
# Validation accuracy: 95.0%
# Minibatch loss at step 14000: 0.193857
# Minibatch accuracy: 96.9%
# Validation accuracy: 95.0%
# Minibatch loss at step 14500: 0.276784
# Minibatch accuracy: 90.6%
# Validation accuracy: 95.0%
# Minibatch loss at step 15000: 0.056015
# Minibatch accuracy: 98.4%
# Validation accuracy: 95.1%
# Minibatch loss at step 15500: 0.258764
# Minibatch accuracy: 90.6%
# Validation accuracy: 95.1%
# Minibatch loss at step 16000: 0.109694
# Minibatch accuracy: 96.9%
# Validation accuracy: 95.2%
# Minibatch loss at step 16500: 0.068959
# Minibatch accuracy: 100.0%
# Validation accuracy: 94.8%
# Minibatch loss at step 17000: 0.125643
# Minibatch accuracy: 95.3%
# Validation accuracy: 95.1%
# Minibatch loss at step 17500: 0.087683
# Minibatch accuracy: 98.4%
# Validation accuracy: 95.2%
# Minibatch loss at step 18000: 0.181763
# Minibatch accuracy: 95.3%
# Validation accuracy: 95.3%
# Minibatch loss at step 18500: 0.096320
# Minibatch accuracy: 98.4%
# Validation accuracy: 95.2%
# Minibatch loss at step 19000: 0.086920
# Minibatch accuracy: 96.9%
# Validation accuracy: 95.4%
# Minibatch loss at step 19500: 0.106348
# Minibatch accuracy: 98.4%
# Validation accuracy: 95.4%
# Minibatch loss at step 20000: 0.195196
# Minibatch accuracy: 95.3%
# Validation accuracy: 95.6%
# Minibatch loss at step 20500: 0.043057
# Minibatch accuracy: 98.4%
# Validation accuracy: 95.4%
# Minibatch loss at step 21000: 0.084616
# Minibatch accuracy: 96.9%
# Validation accuracy: 95.5%
# Minibatch loss at step 21500: 0.132165
# Minibatch accuracy: 96.9%
# Validation accuracy: 95.4%
# Minibatch loss at step 22000: 0.039928
# Minibatch accuracy: 98.4%
# Validation accuracy: 95.5%
# Minibatch loss at step 22500: 0.103443
# Minibatch accuracy: 96.9%
# Validation accuracy: 95.5%
# Minibatch loss at step 23000: 0.045190
# Minibatch accuracy: 100.0%
# Validation accuracy: 95.6%
# Minibatch loss at step 23500: 0.215744
# Minibatch accuracy: 92.2%
# Validation accuracy: 95.6%
# Minibatch loss at step 24000: 0.033360
# Minibatch accuracy: 100.0%
# Validation accuracy: 95.6%
# Minibatch loss at step 24500: 0.164998
# Minibatch accuracy: 93.8%
# Validation accuracy: 95.7%
# Minibatch loss at step 25000: 0.186210
# Minibatch accuracy: 93.8%
# Validation accuracy: 95.5%
# Minibatch loss at step 25500: 0.173621
# Minibatch accuracy: 95.3%
# Validation accuracy: 95.6%
# Minibatch loss at step 26000: 0.101048
# Minibatch accuracy: 96.9%
# Validation accuracy: 95.7%
# Minibatch loss at step 26500: 0.101547
# Minibatch accuracy: 93.8%
# Validation accuracy: 95.7%
# Minibatch loss at step 27000: 0.182785
# Minibatch accuracy: 96.9%
# Validation accuracy: 95.8%
# Minibatch loss at step 27500: 0.080514
# Minibatch accuracy: 98.4%
# Validation accuracy: 95.8%
# Minibatch loss at step 28000: 0.059629
# Minibatch accuracy: 100.0%
# Validation accuracy: 95.8%
# Minibatch loss at step 28500: 0.187272
# Minibatch accuracy: 95.3%
# Validation accuracy: 95.8%
# Minibatch loss at step 29000: 0.215828
# Minibatch accuracy: 92.2%
# Validation accuracy: 95.8%
# Minibatch loss at step 29500: 0.059174
# Minibatch accuracy: 96.9%
# Validation accuracy: 95.9%
# Minibatch loss at step 30000: 0.135044
# Minibatch accuracy: 95.3%
# Validation accuracy: 95.8%
# Minibatch loss at step 30500: 0.250843
# Minibatch accuracy: 92.2%
# Validation accuracy: 95.9%
# Minibatch loss at step 31000: 0.211702
# Minibatch accuracy: 92.2%
# Validation accuracy: 95.9%
# Minibatch loss at step 31500: 0.080501
# Minibatch accuracy: 96.9%
# Validation accuracy: 95.8%
# Minibatch loss at step 32000: 0.080650
# Minibatch accuracy: 96.9%
# Validation accuracy: 95.9%
# Minibatch loss at step 32500: 0.130733
# Minibatch accuracy: 95.3%
# Validation accuracy: 95.9%
# Minibatch loss at step 33000: 0.095648
# Minibatch accuracy: 96.9%
# Validation accuracy: 95.9%
# Minibatch loss at step 33500: 0.169996
# Minibatch accuracy: 95.3%
# Validation accuracy: 95.8%
# Minibatch loss at step 34000: 0.394029
# Minibatch accuracy: 92.2%
# Validation accuracy: 95.8%
# Minibatch loss at step 34500: 0.225500
# Minibatch accuracy: 93.8%
# Validation accuracy: 95.9%
# Minibatch loss at step 35000: 0.061551
# Minibatch accuracy: 98.4%
# Validation accuracy: 95.8%
# Minibatch loss at step 35500: 0.121153
# Minibatch accuracy: 93.8%
# Validation accuracy: 96.0%
# Minibatch loss at step 36000: 0.218043
# Minibatch accuracy: 95.3%
# Validation accuracy: 96.0%
# Minibatch loss at step 36500: 0.091731
# Minibatch accuracy: 96.9%
# Validation accuracy: 96.0%
# Minibatch loss at step 37000: 0.159944
# Minibatch accuracy: 93.8%
# Validation accuracy: 96.0%
# Minibatch loss at step 37500: 0.216506
# Minibatch accuracy: 93.8%
# Validation accuracy: 96.0%
# Minibatch loss at step 38000: 0.266603
# Minibatch accuracy: 92.2%
# Validation accuracy: 96.0%
# Minibatch loss at step 38500: 0.184349
# Minibatch accuracy: 93.8%
# Validation accuracy: 96.0%
# Minibatch loss at step 39000: 0.135586
# Minibatch accuracy: 95.3%
# Validation accuracy: 96.1%
# Minibatch loss at step 39500: 0.233786
# Minibatch accuracy: 93.8%
# Validation accuracy: 96.0%
# Minibatch loss at step 40000: 0.056349
# Minibatch accuracy: 96.9%
# Validation accuracy: 96.0%
# Minibatch loss at step 40500: 0.144035
# Minibatch accuracy: 93.8%
# Validation accuracy: 96.1%
# Minibatch loss at step 41000: 0.059130
# Minibatch accuracy: 98.4%
# Validation accuracy: 96.0%
# Minibatch loss at step 41500: 0.090870
# Minibatch accuracy: 96.9%
# Validation accuracy: 96.1%
# Minibatch loss at step 42000: 0.168273
# Minibatch accuracy: 93.8%
# Validation accuracy: 96.0%
# Minibatch loss at step 42500: 0.084341
# Minibatch accuracy: 96.9%
# Validation accuracy: 96.0%
# Minibatch loss at step 43000: 0.085083
# Minibatch accuracy: 96.9%
# Validation accuracy: 96.1%
# Minibatch loss at step 43500: 0.264962
# Minibatch accuracy: 93.8%
# Validation accuracy: 96.1%
# Minibatch loss at step 44000: 0.368725
# Minibatch accuracy: 90.6%
# Validation accuracy: 96.1%
# Minibatch loss at step 44500: 0.065759
# Minibatch accuracy: 98.4%
# Validation accuracy: 96.2%
# Minibatch loss at step 45000: 0.194075
# Minibatch accuracy: 95.3%
# Validation accuracy: 96.2%
# Minibatch loss at step 45500: 0.231150
# Minibatch accuracy: 90.6%
# Validation accuracy: 96.2%
# Minibatch loss at step 46000: 0.056646
# Minibatch accuracy: 98.4%
# Validation accuracy: 96.2%
# Minibatch loss at step 46500: 0.073774
# Minibatch accuracy: 98.4%
# Validation accuracy: 96.2%
# Minibatch loss at step 47000: 0.099683
# Minibatch accuracy: 96.9%
# Validation accuracy: 96.2%
# Minibatch loss at step 47500: 0.096673
# Minibatch accuracy: 96.9%
# Validation accuracy: 96.2%
# Minibatch loss at step 48000: 0.162030
# Minibatch accuracy: 95.3%
# Validation accuracy: 96.3%
# Minibatch loss at step 48500: 0.086328
# Minibatch accuracy: 98.4%
# Validation accuracy: 96.2%
# Minibatch loss at step 49000: 0.134397
# Minibatch accuracy: 93.8%
# Validation accuracy: 96.2%
# Minibatch loss at step 49500: 0.048726
# Minibatch accuracy: 96.9%
# Validation accuracy: 96.1%
# Minibatch loss at step 50000: 0.119379
# Minibatch accuracy: 95.3%
# Validation accuracy: 96.3%
# Minibatch loss at step 50500: 0.100599
# Minibatch accuracy: 96.9%
# Validation accuracy: 96.1%
# Minibatch loss at step 51000: 0.150022
# Minibatch accuracy: 95.3%
# Validation accuracy: 96.1%
# Minibatch loss at step 51500: 0.101196
# Minibatch accuracy: 98.4%
# Validation accuracy: 96.2%
# Minibatch loss at step 52000: 0.283457
# Minibatch accuracy: 93.8%
# Validation accuracy: 96.2%
# Minibatch loss at step 52500: 0.185583
# Minibatch accuracy: 96.9%
# Validation accuracy: 96.3%
# Minibatch loss at step 53000: 0.074672
# Minibatch accuracy: 98.4%
# Validation accuracy: 96.3%
# Minibatch loss at step 53500: 0.070375
# Minibatch accuracy: 100.0%
# Validation accuracy: 96.3%
# Minibatch loss at step 54000: 0.102964
# Minibatch accuracy: 96.9%
# Validation accuracy: 96.3%
# Minibatch loss at step 54500: 0.056828
# Minibatch accuracy: 98.4%
# Validation accuracy: 96.3%
# Minibatch loss at step 55000: 0.083775
# Minibatch accuracy: 96.9%
# Validation accuracy: 96.3%
# Minibatch loss at step 55500: 0.012522
# Minibatch accuracy: 100.0%
# Validation accuracy: 96.4%
# Minibatch loss at step 56000: 0.090958
# Minibatch accuracy: 96.9%
# Validation accuracy: 96.3%
# Minibatch loss at step 56500: 0.151921
# Minibatch accuracy: 95.3%
# Validation accuracy: 96.4%
# Minibatch loss at step 57000: 0.098591
# Minibatch accuracy: 96.9%
# Validation accuracy: 96.3%
# Minibatch loss at step 57500: 0.273697
# Minibatch accuracy: 95.3%
# Validation accuracy: 96.3%
# Minibatch loss at step 58000: 0.125853
# Minibatch accuracy: 98.4%
# Validation accuracy: 96.2%
# Minibatch loss at step 58500: 0.023797
# Minibatch accuracy: 100.0%
# Validation accuracy: 96.4%
# Minibatch loss at step 59000: 0.116730
# Minibatch accuracy: 96.9%
# Validation accuracy: 96.2%
# Minibatch loss at step 59500: 0.154612
# Minibatch accuracy: 96.9%
# Validation accuracy: 96.2%
# Minibatch loss at step 60000: 0.130566
# Minibatch accuracy: 96.9%
# Validation accuracy: 96.4%
# Minibatch loss at step 60500: 0.108086
# Minibatch accuracy: 98.4%
# Validation accuracy: 96.3%
# Minibatch loss at step 61000: 0.100397
# Minibatch accuracy: 96.9%
# Validation accuracy: 96.5%
# Minibatch loss at step 61500: 0.021160
# Minibatch accuracy: 100.0%
# Validation accuracy: 96.4%
# Minibatch loss at step 62000: 0.123724
# Minibatch accuracy: 98.4%
# Validation accuracy: 96.4%
# Minibatch loss at step 62500: 0.202848
# Minibatch accuracy: 96.9%
# Validation accuracy: 96.4%
# Minibatch loss at step 63000: 0.100338
# Minibatch accuracy: 96.9%
# Validation accuracy: 96.4%
# Minibatch loss at step 63500: 0.025976
# Minibatch accuracy: 98.4%
# Validation accuracy: 96.4%
# Minibatch loss at step 64000: 0.032736
# Minibatch accuracy: 100.0%
# Validation accuracy: 96.5%
# Minibatch loss at step 64500: 0.134423
# Minibatch accuracy: 98.4%
# Validation accuracy: 96.4%
# Minibatch loss at step 65000: 0.210643
# Minibatch accuracy: 96.9%
# Validation accuracy: 96.5%
# Minibatch loss at step 65500: 0.091701
# Minibatch accuracy: 96.9%
# Validation accuracy: 96.3%
# Minibatch loss at step 66000: 0.093310
# Minibatch accuracy: 96.9%
# Validation accuracy: 96.4%
# Minibatch loss at step 66500: 0.062446
# Minibatch accuracy: 96.9%
# Validation accuracy: 96.3%
# Minibatch loss at step 67000: 0.035632
# Minibatch accuracy: 100.0%
# Validation accuracy: 96.4%
# Minibatch loss at step 67500: 0.252152
# Minibatch accuracy: 95.3%
# Validation accuracy: 96.3%
# Minibatch loss at step 68000: 0.195526
# Minibatch accuracy: 95.3%
# Validation accuracy: 96.3%
# Minibatch loss at step 68500: 0.095706
# Minibatch accuracy: 96.9%
# Validation accuracy: 96.4%
# Minibatch loss at step 69000: 0.056366
# Minibatch accuracy: 98.4%
# Validation accuracy: 96.4%
# Minibatch loss at step 69500: 0.059244
# Minibatch accuracy: 98.4%
# Validation accuracy: 96.5%
# Minibatch loss at step 70000: 0.013386
# Minibatch accuracy: 100.0%
# Validation accuracy: 96.5%
# Minibatch loss at step 70500: 0.084104
# Minibatch accuracy: 96.9%
# Validation accuracy: 96.4%
# Minibatch loss at step 71000: 0.233114
# Minibatch accuracy: 95.3%
# Validation accuracy: 96.4%
# Minibatch loss at step 71500: 0.143337
# Minibatch accuracy: 96.9%
# Validation accuracy: 96.4%
# Minibatch loss at step